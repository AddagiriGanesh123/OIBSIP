# %%
#Unemployment Analysis Using Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
#Take the data and primarilary create the data frame
df=pd.read_csv('/content/Unemployment in India.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.shape
# Out:
# (768, 7)

# %%
#Check if the data contains the missing values are not
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
#To drop the null values from the data set
drop=df.dropna()
drop
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.dropna()
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
#If we wanrt to fill agian null value sin the data set by this method
df.fillna(value=0)
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763               0            0          0                              0.00
# 764               0            0          0                              0.00
# 765               0            0          0                              0.00
# 766               0            0          0                              0.00
# 767               0            0          0                              0.00
#
# ...

# %%
#So here we dropped agian to get the better clarification abouut the null values by asssigning  a new variable called s.
s=df.dropna()
s
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
#Checking the number of rows and columns after dropping null values
s.shape
# Out:
# (740, 7)

# %%
#Checking whether the Nan values are eradicated or not.
s.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#Slicing
s.iloc[1:15,:5]
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 1   Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2   Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3   Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4   Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5   Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6   Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7   Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8   Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9   Andhra Pradesh   29-02-2020    Monthly                              5.91
# 10  Andhra Pradesh   31-03-2020    Monthly                              4.06
# 11  Andhra Pradesh   30-04-2020    Monthly                             16.29
# ...

# %%
#Rename all the columns
s.columns=["Region","Date","Frequency","Estmiated Unemployment Rate (%)","Estimated Employed","Estimated Participation Rate (%)","Area"]

# %%
print(s)
# Out:
#              Region         Date Frequency  Estmiated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
#Visualisation-correlation between the dataset features.
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(12,10))#12-width,10-height
sns.heatmap(s.corr())
plt.show()
# Out:
# <ipython-input-20-824c4237310d>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# <ipython-input-20-824c4237310d>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(s.corr())

# %%
#Visualise the data to analyse the unemployment rate fot this we have to consider estimated employment for region particularly
#Rename all the columns
s.columns=["Region","Date","Frequency","Estmiated Unemployment Rate (%)","Estimated Employed","Estimated Participation Rate (%)","Area"]
plt.title("Unemployment in India")
sns.histplot(x="Estmiated Unemployment Rate (%)",hue="Region",data=s)
plt.show()

# %%
sns.histplot(x="Estimated Participation Rate (%)",hue="Region",data=s)
# Out:
# <Axes: xlabel='Estimated Participation Rate (%)', ylabel='Count'>

# %%
#See the unemployment rate according to different regions of India
plt.figure(figsize=(12,10))
plt.title(" Estimation of Indian Employment")
sns.histplot(x="Estimated Employed",hue="Region",data=s)
plt.show()

# %%
#create a dashboard to analyse the unemployment rate of each indian state by region
#Here we use sunburst plot
uemp=s[["Area","Region","Estmiated Unemployment Rate (%)"]]
fig=px.sunburst(uemp,path=["Region","Area"],values="Estmiated Unemployment Rate (%)",width=700,height=700,color_continuous_scale="RdY1Gn",title="Employment Rate In India")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Regions -Countplot assured by Regions on the dataframe
sns.countplot(x=df['Region'],palette="bright")
plt.xticks(rotation="vertical")
plt.show()

# %%
#Boxplot Visualisation of Estmiated Unemployment Rate (%)
plt.figure(figsize=(24,7))
sns.boxplot(x='Region',y='Estmiated Unemployment Rate (%)',data=s)
plt.xticks(rotation='vertical')
plt.title('Unemployment Rate')
plt.show()
